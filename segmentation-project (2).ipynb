copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/7b876e0e-d6bd-4b8c-952c-d0899053246c___R.S_HL 0604 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/74b73acb-62f4-435b-bc40-295d4fc117ad___R.S_HL 8292 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/5243e506-339c-4c97-8e1a-86f146aa5684___R.S_HL 8057 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/026bd735-b9f4-4eab-86f3-23df15dbec95___R.S_HL 7938 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/07eae7fd-96f5-4f09-ba7a-1b108987c6af___R.S_HL 0600 copy 3.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/7c7e1c48-88cd-4ea5-8e34-ce9a2a164880___R.S_HL 8300 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/62d6481b-2d3f-4998-83f9-7071b5fd9446___R.S_HL 8290 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/3f1391a0-85c0-41f2-bd64-7bb9e6e6486e___R.S_HL 0618 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/91efc716-495f-4292-a29d-0819af024515___R.S_HL 8009 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/c4b6565f-e6df-47c4-8426-d98081757564___R.S_HL 8013 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/22e495d5-0daa-4cf6-8555-61f26d091b66___R.S_HL 8061 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/854c7bc4-5439-432a-8131-4e37bcb660b3___R.S_HL 7964 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/68a2cb35-42af-4760-ab0d-0abf06e2429a___R.S_HL 8270 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/185137c7-4f0b-4c82-81af-97a710c89e0b___R.S_HL 7962 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/4dfc51c1-3466-4717-b63c-5bd448a68819___R.S_HL 8220 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/2cc203bd-1fdf-40e1-af08-5ab793586fc4___R.S_HL 7971 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/bc45e1c9-7937-4fe6-9601-371df46a60da___R.S_HL 8025 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/6e32f66d-c54c-4df4-9894-e7aa3ff748d9___R.S_HL 0620 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/2c832929-4ee6-4e36-b473-436d49f26413___R.S_HL 7940 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/5e6a8bf0-16ea-4404-a9cf-04fa9abd43ce___R.S_HL 0606.JPG
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/354890d4-ba2a-43b3-a97c-f9108c480ccd___R.S_HL 8174 copy 2.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/7c09e620-aa1a-4516-b97c-fafecba84622___R.S_HL 0637 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/e7acc1f5-27d0-4e72-aec0-a5b102cd9403___R.S_HL 8180 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/086c8cca-951a-4c1d-93b9-e225b628f2fd___R.S_HL 8024 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/d976fc74-23c2-4c34-a068-db120a61fe0f___R.S_HL 5561 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/5cbf30da-f68e-444e-a68a-c7b8eb385421___R.S_HL 7902 copy.jpg
# /kaggle/input/cv25-project-dataset/Project Data/Train/images/Corn_(maize)___healthy/21bcd072-87a4-4a25-b6fe-3d6cb261b879___R.S_HL 8012 copy 2.jpg

# %%
import os
from PIL import Image
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split

# %%
# Set image dimensions
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

# %%
# Define directories
image_dir = '/kaggle/input/cv25-project-dataset/Project Data/Train/images'
mask_dir = '/kaggle/input/segmentation/Segmented Data/Train'

# %%
# Function to load images and masks, resizing them to the target dimensions
def load_images_from_dir(image_dir, mask_dir):
    images = []
    masks = []
    
    image_subfolders = os.listdir(image_dir)
    
    for subfolder in image_subfolders:
        subfolder_image_path = os.path.join(image_dir, subfolder)
        subfolder_mask_path = os.path.join(mask_dir, subfolder)

        if os.path.isdir(subfolder_image_path):
            image_files = os.listdir(subfolder_image_path)

            for image_file in image_files:
                image_path = os.path.join(subfolder_image_path, image_file)
                mask_file = find_mask_for_image(image_file, subfolder_mask_path)
                
                if mask_file:
                    mask_path = os.path.join(subfolder_mask_path, mask_file)
                    
                    try:
                        # Load and resize images and masks
                        image = Image.open(image_path).resize((IMG_WIDTH, IMG_HEIGHT))
                        mask = Image.open(mask_path).resize((IMG_WIDTH, IMG_HEIGHT))
                        
                        # Convert to numpy arrays
                        image = np.array(image)
                        mask = np.array(mask)
                        
                        # Append to lists
                        images.append(image)
                        masks.append(mask)
                    except Exception as e:
                        print(f"Error loading image or mask {image_file}: {e}")
                else:
                    print(f"No matching mask found for image {image_file}. Skipping.")
    
    return np.array(images), np.array(masks)

# %%
# Function to find corresponding masks
# Loop through the mask files to find a match for the image name
def find_mask_for_image(image_file, mask_dir):
    image_name_without_extension = os.path.splitext(image_file)[0]
    mask_files = os.listdir(mask_dir)
    for mask_file in mask_files:
        if image_name_without_extension in mask_file:
            return mask_file
    return None

# %%
# Load the images and masks from the directories

images, masks = load_images_from_dir(image_dir, mask_dir)

# %%
print(f'Loaded {len(images)} images and {len(masks)} masks.')
# Out:
# Loaded 1320 images and 1320 masks.

# %%
# Visualizations
def visualize_samples(images, masks, num_samples=5):
    # Select a few random indices to display
    num_samples = min(num_samples, len(images))
    indices = np.random.choice(len(images), num_samples, replace=False)
    
    plt.figure(figsize=(15, num_samples * 5))
    
    for i, idx in enumerate(indices):
        # Display the image
        plt.subplot(num_samples, 2, i * 2 + 1)
        plt.imshow(images[idx])
        plt.title(f"Image {idx}")
        plt.axis("off")
        
        # Display the mask
        plt.subplot(num_samples, 2, i * 2 + 2)
        plt.imshow(masks[idx], cmap='gray')
        plt.title(f"Mask {idx}")
        plt.axis("off")
    
    plt.tight_layout()
    plt.show()

# Visualize a few samples
visualize_samples(images, masks, num_samples=5)

# %%
# Normalize the images (scaling pixel values to range [0, 1])
images = images / 255.0
# Convert masks to binary values (0 or 1)
masks = (masks > 0).astype(np.float32)

# %%
# Split the dataset into training and validation sets (80% training, 20% validation)

X_train, X_val, Y_train, Y_val = train_test_split(images, masks, test_size=0.2, random_state=42)

# %% [markdown]
# # **Build the U-Net model**

# %%
# Define U-Net blocks
# Define U-Net convolutional block (used in both contracting and expanding paths)

def conv_block(inputs, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, (3, 3), activation="relu", 
                               kernel_initializer="he_normal", padding="same")(inputs)
    x = tf.keras.layers.Dropout(0.1)(x)
    x = tf.keras.layers.Conv2D(num_filters, (3, 3), activation="relu", 
                               kernel_initializer="he_normal", padding="same")(x)
    return x

# %%
# Define U-Net upsampling block (used to combine previous and current features during expansion)

def upsample_block(inputs, conv_prev, num_filters):
    up = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding="same")(inputs)
    concat = tf.keras.layers.concatenate([up, conv_prev])
    conv = conv_block(concat, num_filters)
    return conv

# %%
# Input layer
inputs = tf.keras.layers.Input((IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255.0)(inputs)

# %%
# Contracting path
c1 = conv_block(s, 16)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = conv_block(p1, 32)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = conv_block(p2, 64)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = conv_block(p3, 128)
p4 = tf.keras.layers.MaxPooling2D((2, 2))(c4)

c5 = conv_block(p4, 256)

# %%
# Expanding path
# upsample and concatenate with c4
# upsample and concatenate with c3
# upsample and concatenate with c2
# upsample and concatenate with c1
c6 = upsample_block(c5, c4, 128)
c7 = upsample_block(c6, c3, 64)
c8 = upsample_block(c7, c2, 32)
c9 = upsample_block(c8, c1, 16)

# %%
# Output layer (single channel for binary segmentation, sigmoid activation for probability output)
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

# %%
# Compile the model
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 128, 128,  │          0 │ input_layer[0][0] │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        448 │ lambda[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ conv2d[0][0]      │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │      2,320 │ dropout[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_2[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_4[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │     36,928 │ dropout_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     73,856 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_6[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    147,584 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 8, 8, 128) │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8, 256) │          0 │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 256) │    590,080 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │    131,200 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │    295,040 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ conv2d_10[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │    147,584 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │     32,832 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 32, 32,    │     73,792 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_12[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 32, 32,    │     36,928 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │      8,224 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 64, 64,    │     18,464 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_14[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 64, 64,    │      9,248 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │      2,064 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │      4,624 │ concatenate_3[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_16[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │      2,320 │ dropout_8[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │         17 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,941,105 (7.40 MB)
#  Trainable params: 1,941,105 (7.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss'),
    tf.keras.callbacks.ModelCheckpoint('model.keras', verbose=1, save_best_only=True)
]

# %%
#callbacks = [
#    tf.keras.callbacks.ModelCheckpoint('model.keras', verbose=1, save_best_only=True)
#]

# %%
# Train the model
results = model.fit(
    X_train, 
    Y_train, 
    validation_data=(X_val, Y_val), 
    batch_size=16, 
    epochs=25, 
    callbacks=callbacks
)
model.save('model.h5', save_format='h5')

# Evaluate the model
model.evaluate(X_val, Y_val)
# Out:
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1734020319.383121    1740 service.cc:145] XLA service 0x7f5f34025450 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1734020319.383197    1740 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#  6/66 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.5108 - loss: 0.6931
# I0000 00:00:1734020338.057388    1740 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5194 - loss: 0.6885
# Epoch 1: val_loss improved from inf to 0.59164, saving model to model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 28s 63ms/step - accuracy: 0.5197 - loss: 0.6883 - val_accuracy: 0.7667 - val_loss: 0.5916
# Epoch 2/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.
25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9579 - loss: 0.1148
# Epoch 19: val_loss did not improve from 0.10152
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9577 - loss: 0.1150 - val_accuracy: 0.8761 - val_loss: 0.3187
# Epoch 20/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9073 - loss: 0.2391
# Epoch 20: val_loss did not improve from 0.10152
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9085 - loss: 0.2362 - val_accuracy: 0.9581 - val_loss: 0.1374
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9558 - loss: 0.1459
# [0.13743984699249268, 0.9580778479576111]

# %%
import os
from PIL import Image
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Set image dimensions
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3

# Define directories
image_dir = '/kaggle/input/cv25-project-dataset/Project Data/Train/images'
mask_dir = '/kaggle/input/segmentation/Segmented Data/Train'
val_image_dir = '/kaggle/input/cv25-project-dataset/Project Data/Val/images'
val_mask_dir = '/kaggle/input/segmentation/Segmented Data/Val'

# Function to load images and masks, resizing them to the target dimensions
def load_images_from_dir(image_dir, mask_dir):
    images = []
    masks = []
    
    image_subfolders = os.listdir(image_dir)
    
    for subfolder in image_subfolders:
        subfolder_image_path = os.path.join(image_dir, subfolder)
        subfolder_mask_path = os.path.join(mask_dir, subfolder)

        if os.path.isdir(subfolder_image_path):
            image_files = os.listdir(subfolder_image_path)

            for image_file in image_files:
                image_path = os.path.join(subfolder_image_path, image_file)
                mask_file = find_mask_for_image(image_file, subfolder_mask_path)
                
                if mask_file:
                    mask_path = os.path.join(subfolder_mask_path, mask_file)
                    
                    try:
                        # Load and resize images and masks
                        image = Image.open(image_path).resize((IMG_WIDTH, IMG_HEIGHT))
                        mask = Image.open(mask_path).resize((IMG_WIDTH, IMG_HEIGHT))
                        
                        # Convert to numpy arrays
                        image = np.array(image)
                        mask = np.array(mask)
                        
                        # Append to lists
                        images.append(image)
                        masks.append(mask)
                    except Exception as e:
                        print(f"Error loading image or mask {image_file}: {e}")
                else:
                    print(f"No matching mask found for image {image_file}. Skipping.")
    
    return np.array(images), np.array(masks)

# Function to find corresponding masks
def find_mask_for_image(image_file, mask_dir):
    image_name_without_extension = os.path.splitext(image_file)[0]
    mask_files = os.listdir(mask_dir)
    for mask_file in mask_files:
        if image_name_without_extension in mask_file:
            return mask_file
    return None

# Load training data
images, masks = load_images_from_dir(image_dir, mask_dir)

# Load validation data
X_val_images, Y_val_masks = load_images_from_dir(val_image_dir, val_mask_dir)

# Normalize images and binarize masks
images = images / 255.0
masks = (masks > 0).astype(np.float32)
X_val_images = X_val_images / 255.0
Y_val_masks = (Y_val_masks > 0).astype(np.float32)

# Split training data into training and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(images, masks, test_size=0.2, random_state=42)

# Define U-Net blocks
def conv_block(inputs, num_filters):
    x = tf.keras.layers.Conv2D(num_filters, (3, 3), activation="relu", 
                               kernel_initializer="he_normal", padding="same")(inputs)
    x = tf.keras.layers.Dropout(0.1)(x)
    x = tf.keras.layers.Conv2D(num_filters, (3, 3), activation="relu", 
                               kernel_initializer="he_normal", padding="same")(x)
    return x

def upsample_block(inputs, conv_prev, num_filters):
    up = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding="same")(inputs)
    concat = tf.keras.layers.concatenate([up, conv_prev])
    conv = conv_block(concat, num_filters)
    return conv

# Build U-Net model
inputs = tf.keras.layers.Input((IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS))
s = tf.keras.layers.Lambda(lambda x: x / 255.0)(inputs)

# Contracting path
c1 = conv_block(s, 16)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = conv_block(p1, 32)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = conv_block(p2, 64)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = conv_block(p3, 128)
p4 = tf.keras.layers.MaxPooling2D((2, 2))(c4)

c5 = conv_block(p4, 256)

# Expanding path
c6 = upsample_block(c5, c4, 128)
c7 = upsample_block(c6, c3, 64)
c8 = upsample_block(c7, c2, 32)
c9 = upsample_block(c8, c1, 16)

# Output layer
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

# Compile the model
model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()

# Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss'),
    tf.keras.callbacks.ModelCheckpoint('model.keras', verbose=1, save_best_only=True)
]

# Train the model
results = model.fit(
    X_train, 
    Y_train, 
    validation_data=(X_val_images, Y_val_masks), 
    batch_size=16, 
    epochs=25, 
    callbacks=callbacks
)

# Evaluate the model
eval_results = model.evaluate(X_val_images, Y_val_masks)
print(f'Validation Loss: {eval_results[0]} - Validation Accuracy: {eval_results[1]}')
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 128, 128,  │          0 │ input_layer_1[0]… │
# │                     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 128, 128,  │        448 │ lambda_1[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_19[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 128, 128,  │      2,320 │ dropout_9[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 64, 64,    │          0 │ conv2d_20[0][0]   │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 64, 64,    │      4,640 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 64, 64,    │          0 │ conv2d_21[0][0]   │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 64, 64,    │      9,248 │ dropout_10[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 32, 32,    │          0 │ conv2d_22[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 32, 32,    │     18,496 │ max_pooling2d_5[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 32, 32,    │          0 │ conv2d_23[0][0]   │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 32, 32,    │     36,928 │ dropout_11[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 16, 16,    │          0 │ conv2d_24[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 16, 16,    │     73,856 │ max_pooling2d_6[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, 16, 16,    │          0 │ conv2d_25[0][0]   │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 16, 16,    │    147,584 │ dropout_12[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 8, 8, 128) │          0 │ conv2d_26[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 8, 8, 256) │          0 │ conv2d_27[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 8, 8, 256) │    590,080 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 16, 16,    │    131,200 │ conv2d_28[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 16, 16,    │    295,040 │ concatenate_4[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 16, 16,    │          0 │ conv2d_29[0][0]   │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 16, 16,    │    147,584 │ dropout_14[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 32, 32,    │     32,832 │ conv2d_30[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 32, 32,    │     73,792 │ concatenate_5[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, 32, 32,    │          0 │ conv2d_31[0][0]   │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 32, 32,    │     36,928 │ dropout_15[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 64, 64,    │      8,224 │ conv2d_32[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 64, 64,    │     18,464 │ concatenate_6[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 64, 64,    │          0 │ conv2d_33[0][0]   │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │      9,248 │ dropout_16[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 128, 128,  │      2,064 │ conv2d_34[0][0]   │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │      4,624 │ concatenate_7[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 128, 128,  │          0 │ conv2d_35[0][0]   │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 128, 128,  │      2,320 │ dropout_17[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 128, 128,  │         17 │ conv2d_36[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,941,105 (7.40 MB)
#  Trainable params: 1,941,105 (7.40 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5448 - loss: 0.6934
# Epoch 1: val_loss improved from inf to 0.63859, saving model to model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 25s 61ms/step - accuracy: 0.5469 - loss: 0.6932 - val_accuracy: 0.7739 - val_loss: 0.6386
# Epoch 2/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6821 - loss: 0.6639
# Epoch 2: val_loss improved from 0.63859 to 0.47328, saving model to model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.6837 - loss: 0.6611 - val_accuracy: 0.7916 - val_loss: 0.4733
# Epoch 3/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7873 - loss: 0.4701
# Epoch 3: val_loss improved from 0.47328 to 0.47246, saving model to model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.7873 - loss: 0.4701 - val_accuracy: 0.7907 - val_loss: 0.4725
# Epoch 4/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8004 - loss: 0.4463
# Epoch 4: val_loss improved from 0.47246 to 0.40447, saving model to model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8005 - loss: 0.4460 - val_accuracy: 0.8294 - val_loss: 0.4045
# Epoch 5/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8212 - loss: 0.4084
# Epoch 5: val_loss improved from 0.40447 to 0.37134, saving model to model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8217 - loss: 0.4076 - val_accuracy: 0.8510 - val_loss: 0.3713
# Epoch 6/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8623 - loss: 0.3316
# Epoch 6: val_loss improved from 0.37134 to 0.28573, saving model to model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8624 - loss: 0.3315 - val_accuracy: 0.8832 - val_loss: 0.2857
# Epoch 7/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8971 - loss: 0.2575
# Epoch 7: val_loss did not improve from 0.28573
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8970 - loss: 0.2578 - val_accuracy: 0.8796 - val_loss: 0.3154
# Epoch 8/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8949 - loss: 0.2728
# Epoch 8: val_loss improved from 0.28573 to 0.15838, saving model to model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8958 - loss: 0.2706 - val_accuracy: 0.9392 - val_loss: 0.1584
# Epoch 9/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8974 - loss: 0.2512
# Epoch 9: val_loss did not improve from 0.15838
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8960 - loss: 0.2545 - val_accuracy: 0.8673 - val_loss: 0.3224
# Epoch 10/25
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8866 - loss: 0.2859
# Epoch 10: val_loss did not improve from 0.15838
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8866 - loss: 0.2859 - val_accuracy: 0.8793 - val_loss: 0.2961
# Epoch 11/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8978 - loss: 0.2530
# Epoch 11: val_loss did not improve from 0.15838
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8980 - loss: 0.2525 - val_accuracy: 0.9059 - val_loss: 0.2391
# Epoch 12/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9122 - loss: 0.2284
# Epoch 12: val_loss did not improve from 0.15838
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9123 - loss: 0.2280 - val_accuracy: 0.9058 - val_loss: 0.2404
# Epoch 13/25
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9272 - loss: 0.1933
# Epoch 13: val_loss did not improve from 0.15838
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9276 - loss: 0.1924 - val_accuracy: 0.9385 - val_loss: 0.1628
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9382 - loss: 0.1619
# Validation Loss: 0.1627504825592041 - Validation Accuracy: 0.9384939670562744

# %%
# Plot the training and validation loss
def plot_training_history(history):
    plt.figure(figsize=(12, 5))
    
    # Loss plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    # Accuracy plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# %%
# Visualize predictions
def display_predictions(model, X_val, Y_val, num_samples=5):
    plt.figure(figsize=(15, num_samples * 5))
    
    for i in range(num_samples):
        idx = random.randint(0, len(X_val) - 1)  # Pick a random sample
        
        image = X_val[idx]
        true_mask = Y_val[idx]
        predicted_mask = model.predict(image[np.newaxis, ...])[0]
        
        # Binarize predicted mask for better visualization
        predicted_mask = (predicted_mask > 0.5).astype(np.float32)
        
        # Display the image, true mask, and predicted mask
        plt.subplot(num_samples, 3, i * 3 + 1)
        plt.imshow(image)
        plt.title("Input Image")
        plt.axis("off")
        
        plt.subplot(num_samples, 3, i * 3 + 2)
        plt.imshow(true_mask, cmap='gray')  # Removed the extra indexing
        plt.title("True Mask")
        plt.axis("off")
        
        plt.subplot(num_samples, 3, i * 3 + 3)
        plt.imshow(predicted_mask, cmap='gray')  # Removed the extra indexing
        plt.title("Predicted Mask")
        plt.axis("off")
    
    plt.tight_layout()
    plt.show()

# Call the visualization functions
plot_training_history(results)
display_predictions(model, X_val, Y_val, num_samples=5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# Function to compute confusion matrix for segmentation
def compute_confusion_matrix(y_true, y_pred):
    # Flatten the arrays to 1D
    y_true_flat = y_true.flatten()
    y_pred_flat = (y_pred > 0.5).flatten()  # Binarize predictions for thresholding
    
    # Compute confusion matrix
    cm = confusion_matrix(y_true_flat, y_pred_flat)
    return cm

# Function to plot confusion matrix
def plot_confusion_matrix(cm):
    plt.figure(figsize=(6, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Background', 'Foreground'], 
                yticklabels=['Background', 'Foreground'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Compute confusion matrix for the whole validation set
all_preds = model.predict(X_val)
cm = compute_confusion_matrix(Y_val, all_preds)

# Plot confusion matrix
plot_confusion_matrix(cm)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, f1_score
import numpy as np

# Function to compute precision, recall, accuracy, and F1 score
def compute_metrics(y_true, y_pred):
    # Flatten the arrays to 1D
    y_true_flat = y_true.flatten()
    y_pred_flat = (y_pred > 0.5).flatten()  # Binarize predictions for thresholding
    
    # Confusion matrix
    cm = confusion_matrix(y_true_flat, y_pred_flat)
    
    # Compute metrics
    precision = precision_score(y_true_flat, y_pred_flat)
    recall = recall_score(y_true_flat, y_pred_flat)
    accuracy = accuracy_score(y_true_flat, y_pred_flat)
    f1 = f1_score(y_true_flat, y_pred_flat)
    
    return cm, precision, recall, accuracy, f1

# Function to display the metrics
def display_metrics(cm, precision, recall, accuracy, f1):
    print("Confusion Matrix:")
    print(cm)
    
    print(f"\nPrecision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"F1 Score: {f1:.4f}")

# Evaluate on the whole validation set
all_preds = model.predict(X_val)

# Compute metrics
cm, precision, recall, accuracy, f1 = compute_metrics(Y_val, all_preds)

# Display the metrics
display_metrics(cm, precision, recall, accuracy, f1)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Confusion Matrix:
# [[1911170   60502]
#  [ 229216 2124488]]
#
# Precision: 0.9723
# Recall: 0.9026
# Accuracy: 0.9330
# F1 Score: 0.9362
